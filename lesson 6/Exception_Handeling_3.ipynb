# %% [markdown]
# # 🧩 Exception Handeling

# %% [markdown]
# # 🎯 1.General Exception
# # 🎯 2. Custom Exception
# # 🎯 3. raise Keyword
# # 🎯 4. Assert Keyword

# %% [markdown]
# # 🚀 1.General Exception

# %%
a = 5
b = 0
c = 10

try:
    #r = '2' + '2'
    #x = y + z
    d = a / b

    print(d)
    print("hello")


except ZeroDivisionError:
    print("ERROR !")

except NameError:
    print("name Error ! ")

except TypeError as t:
    print("No Output! ",t)
# Out:
# ERROR !

# %%
a = 5
b = 0
c = 10

try:
    e = 'i' + 3
    d = a / b

except ZeroDivisionError:
    print("Not Possible !")

except Exception : #General Exception block
    print("Error!!")
# Out:
# Error!!

# %%
a = 5
b = 0
c = 10

try:
    e = 'i' + 3
    d = a / b

except ZeroDivisionError:
    print("Not Possible !")

except Exception as e: #General Exception block
    print("system Error!!",e)
# Out:
# system Error!! can only concatenate str (not "int") to str

# %% [markdown]
# # 🚀 2. Custom Exception

# %% [markdown]
# # (1) raise Keyword
# # (2) assert Keyword

# %%
class User(Exception):
    pass

a =int(input("Enter your number: "))

if a<50:
    raise ZeroDivisionError
else:
    print("your number is",a)
# Out:
# Enter your number: 49
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-2992835652.py in <cell line: 0>()
#       5
#       6 if a<50:
# ----> 7     raise ZeroDivisionError
#       8 else:
#       9     print("your number is",a)
#
# ZeroDivisionError:

# %% [markdown]
# # in Other programming language we are usning throw

# %%
class User(Exception):
    pass

a =int(input("Enter your number: "))

if a<50:
    raise ZeroDivisionError("With zero divison not possible") #message
else:
    print("your number is",a)
# Out:
# Enter your number: 12
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [5], in <cell line: 6>()
#       4 a =int(input("Enter your number: "))
#       6 if a<50:
# ----> 7     raise ZeroDivisionError("With zero divison not possible") #message
#       8 else:
#       9     print("your number is",a)
#
# ZeroDivisionError: With zero divison not possible

# %%
class User(Exception):
    def __init__(self,msg):
        print("Constructor")

a = int(input("Enter your number: "))

if a < 50:
    raise ZeroDivisionError("With zero divison not possible") #message
else:
    print("your number is",a)
# Out:
# Enter your number: 2
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [6], in <cell line: 7>()
#       5 a = int(input("Enter your number: "))
#       7 if a < 50:
# ----> 8     raise ZeroDivisionError("With zero divison not possible") #message
#       9 else:
#      10     print("your number is",a)
#
# ZeroDivisionError: With zero divison not possible

# %%
class User(Exception):
    pass

a = int(input("Enter your number: "))

if a < 50:
    raise ZeroDivisionError("With zero divison not possible") #message
else:
    print("your number is",a)
# Out:
# Enter your number: 26
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [7], in <cell line: 6>()
#       4 a = int(input("Enter your number: "))
#       6 if a < 50:
# ----> 7     raise ZeroDivisionError("With zero divison not possible") #message
#       8 else:
#       9     print("your number is",a)
#
# ZeroDivisionError: With zero divison not possible

# %% [markdown]
# # assert

# %%
a = int(input("Enter your number: "))

#lets assume your age is 18 or graterthan 18 so you can vote !

assert a >= 18

print("Let's Vote !")
# Out:
# Enter your number: 18
# Let's Vote !

# %%
a = int(input("Enter your number: "))

#lets assume your age is 18 or graterthan 18 so you can vote !

assert a >= 18,"age must be above 18"

print("Let's Vote !")
# Out:
# Enter your number: 17
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-539393918.py in <cell line: 0>()
#       3 #lets assume your age is 18 or graterthan 18 so you can vote !
#       4
# ----> 5 assert a >= 18,"age must be above 18"
#       6
#       7 print("Let's Vote !")
#
# AssertionError: age must be above 18

# %%
a = int(input("Enter your number: "))

#lets assume your age is 18 or graterthan 18 so you can vote !

try:
    assert a>=18,"age must be above 18"

except Exception as e:
    print(e)


print("Let's Vote !")
# Out:
# Enter your number: 17
# age must be above 18
# Let's Vote !

# %%
a = int(input("Enter your number: "))

#lets assume your age is 18 or graterthan 18 so you can vote !

try:
    assert a>=18,"age must be above 18"

except Exception as e:
    print(e)

else:
    print("Let's Vote !")
# Out:
# Enter your number: 17
# age must be above 18

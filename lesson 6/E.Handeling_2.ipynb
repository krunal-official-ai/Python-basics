# %% [markdown]
# # -- File Handling

# %% [markdown]
# # # Most Computer programs work with files. this is beacause files Help in storing information permanentely.
#
# # # Word processors create document files
#
# # # Database programs create file of information
#
# # # Compiler read source file and generate executable files
#
# # # So we see it is the files that are mostly worked with inside programs.

# %% [markdown]
# # 🎯 Opening & Closing Files

# %% [markdown]
# # In order to work with a file from within a python program,you need to open it in a specific mode. as per the file manipulation task include adding, modifying or deleting data in a file, which in turn include any one or combination of folowing operations :

# %%
| Mode | Meaning                   |
| ---- | ------------------------- |
|  r   | Read (default)            |
|  w   | Write (creates/truncates) |
|  a   | Append                    |
|  x   | create a file             |

# %% [markdown]
# # python provides built-in functions to perform each of these tasks.
#
# # but before you can perform these perform functions on a file, you need to first open the file .

# %% [markdown]
# # 🧩 Opening Files & Reading a File

# %% [markdown]
# # In data file handeling through python, the first thing that you do is open the file it is done using open( ) function as per below syntax:

# %%
# syntax..
file Object name = open(file name)
file Object name = open(file name,mode)

file = open("example.txt", "r")
#/Users/mac/Desktop/RnW/PythonFolder/CodeS/11.

# %%
#file = open("E:\Ai-ml\Frist.txt","r")
file = open(r"E:\ai-ml\first.txt", "r")

print(file.read())
# Out:
# Third
# Fourth
# Hello your value saved Sucessfully!!!

# %% [markdown]
# # For Windows user

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

print(file.read(10))
# Out:
# Third
# Four

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

print(file.readline())
# Out:
# Third

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

print(file.readline())
print(file.readline())
print(file.readline())
# Out:
# Third
#
# Fourth
#
# Hello your value saved Sucessfully!!!

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

print(file.readlines())
# Out:
# ['Third\n', 'Fourth\n', 'Hello your value saved Sucessfully!!!']

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

for i in file:
    print(i)
# Out:
# Third
#
# Fourth
#
# Hello your value saved Sucessfully!!!

# %%
file.close()

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

print(file.read())
file.close()
# Out:
# Third
# Fourth
# Hello your value saved Sucessfully!!!

# %%
file = open(r"C:\Users\krunal sir\Desktop\11\First.txt","r")

print(file.read())
file.close()
# Out:
# Third
# Fourth
# Hello your value saved Sucessfully!!!

# %%
try:
    file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./third.txt","r")
    print(file.read())
except FileNotFoundError :
    print("File is missing !!")
finally :
    file.close()
# Out:
# File is missing !!

# %%
try:
    file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./third.txt","r")
    print(file.read())
except FileNotFoundError :
    print("File is missing !!")
finally :
    try:
        file.close()
    except:
        print("Connection is not Establish !!")
# Out:
# File is missing !!

# %%
try:
    file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","r")
    print(file.read())
except FileNotFoundError :
    print("File is missing !!")
finally :
    try:
        file.close()
    except:
        print("Connection is not Establish !!")
# Out:
# Hello .. Ai
# Im your Chat bot.. How may I help you ?

# %% [markdown]
# # Short method to write a file

# %%
with open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","r") as F:
        print(F.read())
# Out:
# Hello .. Ai
# Im your Chat bot.. How may I help you ?

# %% [markdown]
# # 🧩 Writing A Files

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./Second.txt","w")

print(file.write(" Can i Do something for you ! "))

file.close()
# Out:
# 30

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./Second.txt","w")

print(file.write(" Can i Do something for you ! "))
print(file.write(" \n Hello "))
print(file.write(" \n Hi.. "))

file.close()
# Out:
# 30
# 8
# 8

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./Second.txt","w")

print(file.write(" Can i Do something for you ! "))
print(file.write(" \n Hello "))
print(file.write(" \n Hi.. "))

print(file.read())


file.close()
# Out:
# 30
# 9
# 8
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [50], in <cell line: 7>()
#       4 print(file.write(" \n Hello "))
#       5 print(file.write(" \n Hi.. "))
# ----> 7 print(file.read())
#      10 file.close()
#
# UnsupportedOperation: not readable

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./Second.txt","w")

print(file.write(" Can i Do something for you ! "))
print(file.write(" \n Hello "))
print(file.write(" \n Hi.. "))
file.close()

file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./Second.txt","r")

print(file.read())
# Out:
# 30
# 9
# 8
#  Can i Do something for you !
#  Hello
#  Hi..

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","w")

X = ["First","second"]

print(file.writelines(X))

file.close()
# Out:
# None

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","w")

X = ["First\n","second\n"]

print(file.writelines(X))

file.close()
# Out:
# None

# %% [markdown]
# # Append Mode

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","a")

X = ["\nThird\n","Fourth\n"]

X.append("\n Hello your value saved Sucessfully!!!")

print(file.writelines(X))

file.close()
# Out:
# None

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","a")

X = ["Third\n","Fourth\n"]

X.append("Hello your value saved Sucessfully!!!")

print(file.writelines(X))

print(file.read()) # can not read file before close

file.close()
# Out:
# None
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Input In [5], in <cell line: 9>()
#       5 X.append("Hello your value saved Sucessfully!!!")
#       7 print(file.writelines(X))
# ----> 9 print(file.read())
#      11 file.close()
#
# UnsupportedOperation: not readable

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","a")

X = ["Third\n","Fourth\n"]

X.append("Hello your value saved Sucessfully!!!")

print(file.writelines(X))

file.close()


file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","r")
print(file.read()) # read file After close writelines
# Out:
# None
# First
# second
# Third
# Fourth
#  Hello your value saved Sucessfully!!! Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","r+")

X = ["Third\n","Fourth\n"]

X.append("Hello your value saved Sucessfully!!!")

print(file.writelines(X))

print(file.read()) # we can write & Read files with r+

file.close()
# Out:
# None
# Sucessfully!!! Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!Third
# Fourth
# Hello your value saved Sucessfully!!!

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./First.txt","w+")

X = ["Third\n","Fourth\n"]

X.append("Hello your value saved Sucessfully!!!")

print(file.writelines(X))

print(file.read()) # we can write files with w+ we can not read a files
file.close()
# Out:
# None

# %% [markdown]
# # =================================

# %% [markdown]
# # Creating New file [Student] in Folder with Read function

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./student.txt","r")

print(file.read())

file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./student.txt","r")
#       3 print(file.read()) # we can write files with w+ we can not read a files
#       5 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./student.txt'

# %% [markdown]
# # Creating New file [Student] in Folder with write function

# %% [markdown]
# # we can create file and we add text in file !

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./student.txt","w")

print(file.write("Hello world How may i help you ! "))

file.close()
# Out:
# 33

# %% [markdown]
# # if we want to create file and don't want to add text in file !

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./Stud.txt","w")

file.close()

# %% [markdown]
# # But Developers are using to create filee !

# %%
file = open("/Users/mac/Desktop/RnW/PythonFolder/CodeS/11./Employee.txt","x")

file.close()

# %% [markdown]
#  # # Some Extra Work for Understanding

# %%
a = 5
b = 0
c = 10

try:
    d = a/b
    print(d)
except ZeroDivisionError:
    print("we can't do !")
# Out:
# we can't do !

# %%
a = 5
b = 0
c = 10

try:
    d = a/b
    print(d)
    print("hello")

except ZeroDivisionError:
    print("ERROR !")
# Out:
# ERROR !

# %%
a = 5
b = 0
c = 10

try:
    d = a/c
    print(d)
    print("hello")

except ZeroDivisionError:
    print("ERROR !")
# Out:
# 0.5
# hello

# %%
a = 5
b = 0
c = 10

try:

    x = y+z
    d = a/c
    print(d)
    print("hello")


except ZeroDivisionError:
    print("ERROR !")

except NameError:
    print("name Error ! ")
# Out:
# name Error !

# %%
a = 5
b = 0
c = 10

try:
    r = 2 + '2'
    x = y + z
    d = a / c

    print(d)
    print("hello")


except ZeroDivisionError:
    print("ERROR !")

except NameError:
    print("name Error ! ")

except TypeError:
    print("type Error ! ")
# Out:
# type Error !

# %%
a = 5
b = 0
c = 10

try:
    r = '2' + '2'
    x = y + z
    d = a / c

    print(d)
    print("hello")


except ZeroDivisionError:
    print("ERROR !")

except NameError:
    print("name Error ! ")

except TypeError as t:
    print("No Output! ",t)
# Out:
# name Error !

# %%
a = 5
b = 0
c = 10

try:
    d = a / b
    print(d)
    print("hello")


except Exception: #General Exception block
    print("Error!!")
# Out:
# Error!!

# %%
BaseException
 ├── BaseExceptionGroup
 ├── GeneratorExit
 ├── KeyboardInterrupt
 ├── SystemExit
 └── Exception
      ├── ArithmeticError
      │    ├── FloatingPointError
      │    ├── OverflowError
      │    └── ZeroDivisionError
      ├── AssertionError
      ├── AttributeError
      ├── BufferError
      ├── EOFError
      ├── ExceptionGroup [BaseExceptionGroup]
      ├── ImportError
      │    └── ModuleNotFoundError
      ├── LookupError
      │    ├── IndexError
      │    └── KeyError
      ├── MemoryError
      ├── NameError
      │    └── UnboundLocalError
      ├── OSError
      │    ├── BlockingIOError
      │    ├── ChildProcessError
      │    ├── ConnectionError
      │    │    ├── BrokenPipeError
      │    │    ├── ConnectionAbortedError
      │    │    ├── ConnectionRefusedError
      │    │    └── ConnectionResetError
      │    ├── FileExistsError
      │    ├── FileNotFoundError
      │    ├── InterruptedError
      │    ├── IsADirectoryError
      │    ├── NotADirectoryError
      │    ├── PermissionError
      │    ├── ProcessLookupError
      │    └── TimeoutError
      ├── ReferenceError
      ├── RuntimeError
      │    ├── NotImplementedError
      │    ├── PythonFinalizationError
      │    └── RecursionError
      ├── StopAsyncIteration
      ├── StopIteration
      ├── SyntaxError
      │    └── IndentationError
      │         └── TabError
      ├── SystemError
      ├── TypeError
      ├── ValueError
      │    └── UnicodeError
      │         ├── UnicodeDecodeError
      │         ├── UnicodeEncodeError
      │         └── UnicodeTranslateError
      └── Warning
           ├── BytesWarning
           ├── DeprecationWarning
           ├── EncodingWarning
           ├── FutureWarning
           ├── ImportWarning
           ├── PendingDeprecationWarning
           ├── ResourceWarning
           ├── RuntimeWarning
           ├── SyntaxWarning
           ├── UnicodeWarning
           └── UserWarning

# %%
a = 5
b = 0
c = 10

try:
    d = a / c
    print(d)
    print("hello")


except:
    print("Error!!")

else:
    print("Sucessfull !!")
# Out:
# 0.5
# hello
# Sucessfull !!

# %%
a = 5
b = 0
c = 10

try:
    d = a / c
    print(d)
    print("hello")


except:
    print("Error!!")

else:
    print("Sucessfull !!")

finally:
    print("Alwats Execute in condition")
    # Resources release with help of finally
    # 1. Database
    # 2. File Handeling
# Out:
# 0.5
# hello
# Sucessfull !!
# Alwats Execute in condition

# %% [markdown]
# # TUPLES

# %%
X = ('A' , 59 , 90 ,78 , 10 , 60,78.56,45.67,"Vision")
Y = ("A","B",'V','X',90.05,30,'xyz',"opq",89,79.50) 
Z = ("s","d","g",90)

# %%
print(X) 
print(Y) 
print(Z)
# Out:
# ('A', 59, 90, 78, 10, 60, 78.56, 45.67, 'ai')
# ('A', 'B', 'V', 'X', 90.05, 30, 'xyz', 'opq', 89, 79.5)
# ('s', 'd', 'g', 90)

# %%
print(type(X)) 
print(len(X))
# Out:
# <class 'tuple'>
# 9

# %% [markdown]
# # indexcing # toknization

# %%
T =( 'A' , 59 , 90 ,78 , 10 , 60, 78.56 , 45.67 , "ai" )

# %%
print(T[0])  #indexcing # toknization 
print(T[2]) 
print(T[4]) 
print(T[6]) 
print(T[7])
# Out:
# A
# 90
# 10
# 78.56
# 45.67

# %% [markdown]
# # slicing

# %%
T =( 'A' , 59 , 90 ,78 , 10 , 60, 78.56 , 45.67 , "ai" ) 
print(T[0:5]) #slicing
# Out:
# ('A', 59, 90, 78, 10)

# %%
X = ('A' , 59 , 90 ,78 , 10 , 60,78.56,45.67,"ai")
Y = ("A","B",'V','X',90.05,30,'xyz',"opq",89,79.50) 
Z = ("s","d","g",90) 

print(X[0:]) 
print(Z[:])
# Out:
# ('A', 59, 90, 78, 10, 60, 78.56, 45.67, 'ai')
# ('s', 'd', 'g', 90)

# %% [markdown]
# # concatination

# %%
print (X + Y) #concatination
# Out:
# ('A', 59, 90, 78, 10, 60, 78.56, 45.67, 'ai', 'A', 'B', 'V', 'X', 90.05, 30, 'xyz', 'opq', 89, 79.5)

# %%
X = ('A' , 59 , 90 ,78 , 10 , 60,78.56,45.67,"ai")
Y = ("A","B",'V','X',90.05,30,'xyz',"opq",89,79.50) 
Z = ("s","d","g",90) 

Friday = X + Z

# %%
print(Friday)
# Out:
# ('A', 59, 90, 78, 10, 60, 78.56, 45.67, 'ai', 's', 'd', 'g', 90)
